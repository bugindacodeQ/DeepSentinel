# %% [markdown]
# # 02 — Preprocessing Pipeline
# Face detection, cropping, resizing, and augmentation.

# %%
import sys
sys.path.append('..')
from src.preprocess import TRAIN_TRANSFORMS, INFER_TRANSFORMS, preprocess_image
from PIL import Image
import matplotlib.pyplot as plt

# Test transforms on a sample image
# img_path = '../data/samples/sample.jpg'
# tensor = preprocess_image(img_path)
# print('Tensor shape:', tensor.shape)

# %%
# Augmentation preview
# img = Image.open(img_path).convert('RGB')
# fig, axes = plt.subplots(1, 5, figsize=(15, 3))
# for ax in axes:
#     t = TRAIN_TRANSFORMS(img).permute(1,2,0).numpy()
#     ax.imshow((t - t.min()) / (t.max() - t.min()))
#     ax.axis('off')
# plt.suptitle('Augmentation samples')
# plt.show()
