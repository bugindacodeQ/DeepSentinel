# %% [markdown]
# # 04 — Evaluation
# Compute AUC, F1, accuracy, and visualise the confusion matrix.

# %%
import sys
sys.path.append('..')
from src.evaluate import evaluate

auc = evaluate(
    weights_path='../models/weights/efficientnet_b4.pth',
    test_dir='../data/processed/test',
)
print(f'Test AUC: {auc:.4f}')

# %%
# Confusion matrix visualisation (add after running evaluate)
# from sklearn.metrics import ConfusionMatrixDisplay
# import matplotlib.pyplot as plt
# ConfusionMatrixDisplay.from_predictions(all_labels, preds, display_labels=['REAL','FAKE'])
# plt.title('Confusion Matrix')
# plt.show()
